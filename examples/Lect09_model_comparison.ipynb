# %% [markdown]
# # Модели машинного обучения различной архитектуры: сравнение на реальных данных
#
# И снова здравствуйте, ~~новоземельские белые медведи~~ польские бобры.
#
# Будем решать задачу аппроксимации турбулентных потоков тепла над городскими ландшафтами.
#
# Используются данные международного проекта [Urban Plumber](https://urban-plumber.github.io/) для точки [PL-Lipova](https://urban-plumber.github.io/PL-Lipowa/) в городе Лодзь.
#
# Статья про данные: [Lipson et al. (2022, ESSD) Harmonized gap-filled datasets from 20 urban flux tower sites](https://doi.org/10.5194/essd-14-5157-2022)

# %%
import os, sys
import pickle as pkl
import xarray as xr
import pandas as pd 
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from tqdm import tqdm

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import TransformedTargetRegressor
from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV


from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge   
from sklearn.neighbors import KNeighborsRegressor

from catboost import CatBoostRegressor



def memorysize (obj):
    with open('temp.pkl', 'wb') as f:
        pkl.dump(obj, f)
    size = os.path.getsize('temp.pkl')
    os.remove('temp.pkl')
    return size

# %%
ds = xr.open_dataset ("data4model_comparison/PL-Lipowa_raw_observations_v1.nc")

df = ds.to_dataframe()
df = df.drop(columns = [c for c in df.columns if "_qc" in c])
display(df.head())
display(df.describe())

#df.resample('3H').mean()
df_smoothed = df.groupby(pd.Grouper(freq='3h', closed='left', label='left', convention='start')).mean()
# Out:
#                      SWdown      LWdown        Tair      Qair    PSurf  Rainf  \
# time
# 2008-01-01 00:00:00   -0.05  338.130005  273.040009  0.003802  99700.0    0.0
# 2008-01-01 01:00:00    0.00  339.160004  272.980011  0.003783  99700.0    0.0
# 2008-01-01 02:00:00    0.00  337.899994  272.959991  0.003777  99700.0    0.0
# 2008-01-01 03:00:00    0.00  338.149994  272.920013  0.003765  99700.0    0.0
# 2008-01-01 04:00:00    0.01  338.839996  272.910004  0.003762  99700.0    0.0
#
#                      Snowf  Wind_N  Wind_E  SWup        LWup        Qle     Qh
# time
# 2008-01-01 00:00:00    NaN  -0.255   1.437  0.00  343.760010  97.680000 -1.869
# 2008-01-01 01:00:00    NaN  -0.333   1.501  0.00  343.510010 -11.725000  3.217
# 2008-01-01 02:00:00    NaN  -0.206   1.328  0.00  343.609985  26.704000  0.219
# 2008-01-01 03:00:00    NaN   0.188   0.792  0.45  343.410004  -5.829000  0.352
# 2008-01-01 04:00:00    NaN   0.455   1.039  0.60  343.209991  41.268002 -1.121
#              SWdown        LWdown          Tair          Qair          PSurf  \
# count  43848.000000  43848.000000  43848.000000  43848.000000   43848.000000
# mean     123.889549    344.117676    282.331848      0.006654   98924.929688
# std      205.480896     50.961803      8.913330      0.003236     852.744202
# min       -6.760000    170.149994    254.410004      0.000605   95250.000000
# 25%       -0.730000    312.527496    275.899994      0.004191   98400.000000
# 50%        4.900000    346.510010    282.489990      0.006156   98980.000000
# 75%      166.372501    379.609985    289.230011      0.008769   99450.000000
# max      955.809998    493.380005    307.149994      0.018955  101720.000000
#
#               Rainf  Snowf        Wind_N        Wind_E          SWup  \
# count  43848.000000    0.0  38455.000000  38455.000000  40369.000000
# mean       0.000015    NaN      0.263691      0.468939     13.019703
# std        0.000119    NaN      2.423843      2.431707     18.432878
# min        0.000000    NaN    -10.531000     -8.752000     -4.230000
# 25%        0.000000    NaN     -1.394000     -1.299000      1.370000
# 50%        0.000000    NaN      0.187000      0.675000      2.740000
# 75%        0.000000    NaN      2.130000      2.121000     19.600000
# max        0.007722    NaN     10.599000      9.964000    214.699997
#
#                LWup           Qle            Qh
# count  40369.000000  29193.000000  29196.000000
# mean     399.141083     20.190529     34.463863
# std       59.382599     32.610863     66.810616
# min      255.740005    -98.999001    -98.473999
# 25%      353.779999      2.950000     -5.444500
# 50%      391.700012     11.523000      9.251500
# 75%      439.359985     29.500999     49.053749
# max      616.409973    317.648010    482.760010

# %%
# %matplotlib qt
df['Qh'].plot()
df_smoothed['Qh'].plot()
# Out:
# <Axes: xlabel='time'>

# %%
df4ml = df_smoothed.drop (columns=['Snowf', 'SWup'])
df4ml = df4ml.dropna()
df4ml = df4ml.sample(1000)

df4ml['Wind_vel'] = np.sqrt (df4ml['Wind_N']**2 + df4ml['Wind_E']**2)
sigma = 5.67*(10**-8)

df4ml['Ts'] = (df4ml['LWup'] / sigma) **0.25 - 273.15
df4ml['delta_T'] = df4ml['Ts'] - df4ml['Tair']
df4ml = df4ml.drop (columns=['LWup'])

display(df4ml.describe())
# Out:
#             SWdown       LWdown         Tair         Qair          PSurf  \
# count  1000.000000  1000.000000  1000.000000  1000.000000    1000.000000
# mean    133.553482   345.419250   282.801178     0.006656   98949.101562
# std     205.948563    51.050423     9.098638     0.003304     802.518372
# min      -3.346667   188.673340   256.253326     0.000613   96033.335938
# 25%      -0.395000   309.940002   276.162491     0.004059   98439.166016
# 50%      17.025001   346.059998   283.291672     0.006030   99000.000000
# 75%     199.986664   383.514153   289.857491     0.008909   99476.664062
# max     841.409973   460.163330   305.953339     0.017162  101400.000000
#
#              Rainf       Wind_N       Wind_E          Qle           Qh  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.000008     0.230216     0.453610    19.757328    33.863728
# std       0.000047     2.357878     2.302147    28.262745    63.292084
# min       0.000000    -7.042667    -6.751667   -80.170998   -73.747673
# 25%       0.000000    -1.312750    -1.320667     3.326084    -3.794667
# 50%       0.000000     0.141833     0.595500    12.135916    10.298667
# 75%       0.000000     2.056167     2.155750    29.905249    47.226126
# max       0.000620     6.305334     7.627333   149.470001   370.880493
#
#           Wind_vel           Ts      delta_T
# count  1000.000000  1000.000000  1000.000000
# mean      3.026883    16.817770  -265.983429
# std       1.395459    11.136596     2.873791
# min       0.151068   -11.981842  -270.838196
# 25%       2.075091     8.509323  -267.907585
# 50%       2.871258    16.471130  -266.806305
# 75%       3.762021    24.853378  -265.029770
# max       9.566338    45.906281  -254.666779

# %%
# %matplotlib inline
sns.heatmap (df4ml.corr(), annot=True, cmap="coolwarm", fmt=".2f", annot_kws={'size': 'xx-small'})
# Out:
# <Axes: >

# %%
class BootstrapCV:
    
    def __init__(self, n_splits, sample_size, random_state = 42):
        self.n_splits = n_splits
        self.random_state = random_state
        self.sample_size = sample_size

    def split(self, X, y=None, groups=None):
        np.random.seed (self.random_state)
        for i in range(self.n_splits):
            sample_indices = np.random.randint(0,X.shape[0], self.sample_size)
            oob_indices = np.array([i for i in np.arange(0, X.shape[0], 1, dtype=int) if i not in sample_indices])
            yield sample_indices, oob_indices
    
    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

# %%
target = 'Qle'
X = df4ml.drop (columns=['Qh', 'Qle'])
Y = df4ml[target]

models = [LinearRegression (), 
          KNeighborsRegressor (),
          DecisionTreeRegressor (max_depth=20),
          #RandomForestRegressor (),
          #GradientBoostingRegressor (), 
          GradientBoostingRegressor (learning_rate = 0.03603075049685412, max_depth = 3, n_estimators = 84)] 

#cv = KFold(n_splits=10)
cv = BootstrapCV (n_splits=20, sample_size=int (Y.shape[0]*0.95), random_state = 42)

scores = {}

use_scaler = False

for model in tqdm(models):

    model_pp = Pipeline([
                        ('scaler', StandardScaler(with_mean=use_scaler, with_std=use_scaler)),
                        ('regressor', TransformedTargetRegressor(regressor=model, transformer=StandardScaler(with_mean=use_scaler, with_std=use_scaler)))
                        ])

    scores4model = cross_validate(model_pp, X, Y, cv=cv, n_jobs=8,
                                  scoring=['r2', 'neg_root_mean_squared_error'], return_train_score = True, return_estimator=True, return_indices=True)

    scores4model['train_idx'] = scores4model['indices']['train']
    scores4model['test_idx'] = scores4model['indices']['test']
    scores4model.pop('indices')
    
    scores4model['model'] = model.__class__.__name__
    scores[model.__class__.__name__] = scores4model
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.75it/s]

# %%
scores_df = pd.concat ([pd.DataFrame(scores[model]) for model in scores.keys()], ignore_index=True)

scores_df['test_rmse'] = -scores_df['test_neg_root_mean_squared_error']
scores_df['train_rmse'] = -scores_df['train_neg_root_mean_squared_error']

#scores_df['estimator_memsize'] = [sys.getsizeof(estimator['regressor']) for estimator in scores_df['estimator']]
scores_df['estimator_memsize'] = [memorysize(estimator['regressor']) for estimator in scores_df['estimator']]
scores_df.head()
# Out:
#    fit_time  score_time                                          estimator  \
# 0  0.005493    0.004530  (StandardScaler(with_mean=False, with_std=Fals...
# 1  0.005497    0.002521  (StandardScaler(with_mean=False, with_std=Fals...
# 2  0.006020    0.002999  (StandardScaler(with_mean=False, with_std=Fals...
# 3  0.007031    0.002986  (StandardScaler(with_mean=False, with_std=Fals...
# 4  0.008029    0.003495  (StandardScaler(with_mean=False, with_std=Fals...
#
#     test_r2  train_r2  test_neg_root_mean_squared_error  \
# 0  0.548673  0.452160                        -19.253143
# 1  0.442392  0.532718                        -19.855816
# 2  0.458903  0.567592                        -21.927799
# 3  0.479873  0.537642                        -21.787596
# 4  0.515169  0.505609                        -19.589352
#
#    train_neg_root_mean_squared_error  \
# 0                         -20.569050
# 1                         -20.096754
# 2                         -17.474535
# 3                         -18.293585
# 4                         -20.564745
#
#                                            train_idx  \
# 0  [102, 435, 860, 270, 106, 71, 700, 20, 614, 12...
# 1  [783, 967, 357, 971, 407, 667, 372, 7, 121, 34...
# 2  [147, 466, 738, 243, 490, 848, 957, 506, 364, ...
# 3  [219, 961, 703, 965, 574, 584, 160, 680, 88, 6...
# 4  [480, 145, 830, 627, 112, 762, 475, 762, 302, ...
#
#                                             test_idx             model  \
# 0  [2, 3, 5, 6, 7, 9, 10, 12, 23, 25, 29, 30, 31,...  LinearRegression
# 1  [1, 8, 11, 13, 15, 19, 20, 21, 23, 29, 30, 32,...  LinearRegression
# 2  [3, 4, 5, 12, 14, 17, 18, 22, 25, 29, 31, 33, ...  LinearRegression
# 3  [0, 3, 4, 5, 8, 10, 14, 15, 17, 21, 23, 26, 27...  LinearRegression
# 4  [1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 13, 14, 16, ...  LinearRegression
#
#    test_rmse  train_rmse  estimator_memsize
# 0  19.253143   20.569050                997
# 1  19.855816   20.096754                997
# 2  21.927799   17.474535                997
# 3  21.787596   18.293585                997
# 4  19.589352   20.564745                997

# %% [markdown]
# ## Считаем заново прогнозные значения целевой переменной для тестовой и тренировочной выборок
#
# Это нужно, так как сross_validate их не возвращает, а мы хотим построить диаграмму рассеяния. Записываем их в один большой DataFrame.

# %%
reg_results = []

for i in scores_df.index:
    train_idx = scores_df.loc[i, 'train_idx']
    test_idx =  scores_df.loc[i, 'test_idx']
    
    cur_Y_train = Y.iloc[train_idx]
    cur_Y_test  = Y.iloc[test_idx]

    cur_X_train = X.iloc[train_idx]
    cur_X_test  = X.iloc[test_idx]

    cur_Y_train_pred = scores_df.loc[i, 'estimator'].predict(cur_X_train)
    cur_Y_test_pred  = scores_df.loc[i, 'estimator'].predict(cur_X_test)
    
    reg_results.append (pd.DataFrame({'Y':cur_Y_train, 'Y_pred':cur_Y_train_pred, 'model': scores_df.loc[i,'model'], 'type': 'train'}))
    reg_results.append (pd.DataFrame({'Y':cur_Y_test,  'Y_pred':cur_Y_test_pred,  'model': scores_df.loc[i,'model'], 'type': 'test'}))
    
reg_results = pd.concat(reg_results)

# %% [markdown]
# ## Строим диаграммы рассеяния для разных моделей и выборок (train/test)

# %%
def myhexbin(*args, **kwargs):
        kwargs.pop("color", None)
        hb = plt.hexbin(*args, **kwargs)
        return hb

plt.figure()
g = sns.FacetGrid (reg_results, col = 'model', row='type')
g.map(plt.scatter, 'Y', 'Y_pred', s=1, color = 'black') 
g.map(myhexbin, 'Y', 'Y_pred', mincnt=1, gridsize=18, alpha = 0.5, edgecolor = None) 

for ax in g.axes.flatten():
        ax.set_title(ax.title.get_text().replace('|', '\n'), fontsize='small')
        ax.set_aspect(1) #'equal')
        ax.grid(zorder=0)

# %% [markdown]
# ## Посмотрим на метрики качества и их неопределенность для разных bootstrap-выборок.

# %%
for metric in ['r2', 'rmse']:
    df1 = scores_df[['model', 'train_' + metric]].rename(columns={'train_' + metric: metric,})
    df2 = scores_df[['model', 'test_' + metric]].rename(columns={'test_' + metric: metric,})

    df1['type'] = 'train'
    df2['type'] = 'test'
    df2boxplot = pd.concat([df1, df2])

    plt.figure()
    sns.boxplot (df2boxplot, x='model', y=metric, hue='type', palette='Set1')
    _ = plt.xticks(rotation=45)
    plt.grid()

# %%
plt.figure()
sns.barplot (scores_df, x='model', y='estimator_memsize')
plt.xticks(rotation=45)
plt.yscale('log')

plt.figure()
sns.barplot (scores_df, x='model', y='fit_time')
plt.xticks(rotation=45)
plt.yscale('log')

plt.figure()
sns.barplot (scores_df, x='model', y='score_time')
plt.xticks(rotation=45)
plt.yscale('log')

# %% [markdown]
# ## Оптимизация гиперпараметров методом GridSearch

# %%
cv = BootstrapCV (n_splits=10, sample_size=int (Y.shape[0]*0.95), random_state = 42)

#model = KNeighborsRegressor()
#parameters = {'n_neighbors': [1, 2, 3, 5, 10, 20, 50, 100, 200]}

model = GradientBoostingRegressor()
parameters = {'n_estimators': [20, 50, 100, 200], 'max_depth': [2, 3, 5, 10], 'learning_rate': [0.01, 0.1, 0.2]}

clf = GridSearchCV(model, parameters, cv = cv, n_jobs=8, scoring = 'neg_root_mean_squared_error')
clf.fit(X, Y)
# Out:
# GridSearchCV(cv=<__main__.BootstrapCV object at 0x000001C60B4E64B0>,
#              estimator=GradientBoostingRegressor(), n_jobs=8,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [2, 3, 5, 10],
#                          'n_estimators': [20, 50, 100, 200]},
#              scoring='neg_root_mean_squared_error')

# %%
display (clf.best_params_)
display (clf.cv_results_['mean_test_score'])
#clf.cv_results_
# Out:
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50}
# array([-26.93007152, -24.75748067, -22.67037707, -21.13428369,
#        -26.77314135, -24.47801918, -22.38874245, -21.01757302,
#        -26.65193668, -24.3653903 , -22.45530171, -21.31004509,
#        -26.69296743, -24.64140883, -23.30428871, -22.95508092,
#        -21.08586994, -20.75456786, -20.98564455, -21.29434764,
#        -20.99309743, -20.92419033, -21.25092957, -21.65045326,
#        -21.28203071, -21.26186438, -21.49373121, -21.60424099,
#        -23.02933534, -23.1592863 , -23.24697911, -23.25689877,
#        -20.78332773, -21.08273328, -21.40182171, -21.80839866,
#        -21.02991858, -21.45943736, -21.87520693, -22.19753378,
#        -21.44554168, -21.76619981, -21.93648302, -22.0229851 ,
#        -23.15070268, -23.12125003, -23.23318779, -23.29043495])

# %% [markdown]
# ## Баесова оптимизация с использованием фреймворка Optuna

# %%
import optuna
from optuna.samplers import TPESampler

# Define the objective function
def objective (trial):
    
    # n_neighbors = trial.suggest_int('n_neighbors', 1, 200)
    # weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    # model = KNeighborsRegressor(n_neighbors=n_neighbors, weights=weights)
    
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.5)
    max_depth = trial.suggest_int('max_depth', 2, 10)
    n_estimators = trial.suggest_int('n_estimators', 20, 200)
    model = GradientBoostingRegressor(learning_rate = learning_rate, max_depth = max_depth, n_estimators = n_estimators)
    #model = CatBoostRegressor(learning_rate = learning_rate, max_depth = max_depth, n_estimators = n_estimators, silent=True)
    
    cv = BootstrapCV (n_splits=5, sample_size=int (Y.shape[0]*0.95), random_state = 42)
    scores = cross_val_score(model, X, Y, cv=cv, scoring='neg_root_mean_squared_error')
    return -scores.mean()

# Run the optimization
study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(objective, n_trials=100)

# Print the best hyperparameters and score
print('Best hyperparameters:', study.best_params)
print('Best score:', study.best_value)
# Out:
# [I 2024-12-03 11:53:31,600] A new study created in memory with name: no-name-2e81897c-31fe-4f98-a665-6911e3d5d0ae
# [I 2024-12-03 11:53:32,347] Trial 0 finished with value: 23.05228268121819 and parameters: {'learning_rate': 0.20887606396846303, 'max_depth': 9, 'n_estimators': 21}. Best is trial 0 with value: 23.05228268121819.
# [I 2024-12-03 11:53:35,456] Trial 1 finished with value: 22.199480157520373 and parameters: {'learning_rate': 0.048057749440215354, 'max_depth': 7, 'n_estimators': 118}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:36,901] Trial 2 finished with value: 22.814351672066863 and parameters: {'learning_rate': 0.03194443159281955, 'max_depth': 10, 'n_estimators': 42}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:42,610] Trial 3 finished with value: 23.290107220574058 and parameters: {'learning_rate': 0.4090493798923961, 'max_depth': 9, 'n_estimators': 190}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:43,621] Trial 4 finished with value: 22.50312110826026 and parameters: {'learning_rate': 0.34299022386943573, 'max_depth': 3, 'n_estimators': 79}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:48,389] Trial 5 finished with value: 22.960024462145043 and parameters: {'learning_rate': 0.09162633316984989, 'max_depth': 8, 'n_estimators': 161}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:49,972] Trial 6 finished with value: 22.983620977494848 and parameters: {'learning_rate': 0.35060159803465035, 'max_depth': 7, 'n_estimators': 61}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:55,325] Trial 7 finished with value: 22.60354325347946 and parameters: {'learning_rate': 0.0872335643580622, 'max_depth': 8, 'n_estimators': 184}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:57,147] Trial 8 finished with value: 23.86030071013572 and parameters: {'learning_rate': 0.4880130789577948, 'max_depth': 4, 'n_estimators': 115}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:53:59,719] Trial 9 finished with value: 22.729569878878515 and parameters: {'learning_rate': 0.2045528675363187, 'max_depth': 9, 'n_estimators': 80}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:54:02,284] Trial 10 finished with value: 22.488351825144214 and parameters: {'learning_rate': 0.1432131232132513, 'max_depth': 5, 'n_estimators': 130}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:54:04,709] Trial 11 finished with value: 22.438328487521822 and parameters: {'learning_rate': 0.13276393389944907, 'max_depth': 5, 'n_estimators': 126}. Best is trial 1 with value: 22.199480157520373.
# [I 2024-12-03 11:54:07,875] Trial 12 finished with value: 21.65585275598992 and parameters: {'learning_rate': 0.02757289948248648, 'max_depth': 6, 'n_estimators': 142}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:11,243] Trial 13 finished with value: 21.900316876114573 and parameters: {'learning_rate': 0.024530925536111386, 'max_depth': 6, 'n_estimators': 151}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:14,649] Trial 14 finished with value: 21.970958959010268 and parameters: {'learning_rate': 0.02994516315742504, 'max_depth': 6, 'n_estimators': 153}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:16,104] Trial 15 finished with value: 22.96028424378779 and parameters: {'learning_rate': 0.25976778617772106, 'max_depth': 2, 'n_estimators': 161}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:18,146] Trial 16 finished with value: 21.848779138139513 and parameters: {'learning_rate': 0.1515147463808661, 'max_depth': 6, 'n_estimators': 90}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:19,669] Trial 17 finished with value: 21.978535277197544 and parameters: {'learning_rate': 0.16275491808559717, 'max_depth': 4, 'n_estimators': 93}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:22,308] Trial 18 finished with value: 22.631159170713637 and parameters: {'learning_rate': 0.2636719963946089, 'max_depth': 5, 'n_estimators': 138}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:24,571] Trial 19 finished with value: 21.714421348629465 and parameters: {'learning_rate': 0.09076692870004624, 'max_depth': 7, 'n_estimators': 88}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:27,256] Trial 20 finished with value: 22.037649703153683 and parameters: {'learning_rate': 0.09330624499170428, 'max_depth': 7, 'n_estimators': 99}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:28,796] Trial 21 finished with value: 22.244413367029583 and parameters: {'learning_rate': 0.19316866129533217, 'max_depth': 6, 'n_estimators': 64}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:31,551] Trial 22 finished with value: 22.114565990047033 and parameters: {'learning_rate': 0.08838331202730149, 'max_depth': 7, 'n_estimators': 105}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:34,004] Trial 23 finished with value: 22.262121607611547 and parameters: {'learning_rate': 0.12467858807678567, 'max_depth': 8, 'n_estimators': 84}. Best is trial 12 with value: 21.65585275598992.
# [I 2024-12-03 11:54:35,225] Trial 24 finished with value: 21.40079040056839 and parameters: {'learning_rate': 0.06207036089094625, 'max_depth': 5, 'n_estimators': 62}. Best is trial 24 with value: 21.40079040056839.
# [I 2024-12-03 11:54:36,170] Trial 25 finished with value: 21.358706721937487 and parameters: {'learning_rate': 0.0638576967814216, 'max_depth': 4, 'n_estimators': 57}. Best is trial 25 with value: 21.358706721937487.
# [I 2024-12-03 11:54:36,853] Trial 26 finished with value: 21.345788299454018 and parameters: {'learning_rate': 0.06085908313010012, 'max_depth': 4, 'n_estimators': 40}. Best is trial 26 with value: 21.345788299454018.
# [I 2024-12-03 11:54:37,348] Trial 27 finished with value: 21.301459630860855 and parameters: {'learning_rate': 0.05905433277090116, 'max_depth': 3, 'n_estimators': 35}. Best is trial 27 with value: 21.301459630860855.
# [I 2024-12-03 11:54:37,622] Trial 28 finished with value: 21.602524323852656 and parameters: {'learning_rate': 0.060796195083312944, 'max_depth': 2, 'n_estimators': 26}. Best is trial 27 with value: 21.301459630860855.
# [I 2024-12-03 11:54:37,936] Trial 29 finished with value: 21.59539837364819 and parameters: {'learning_rate': 0.2341683853140239, 'max_depth': 3, 'n_estimators': 20}. Best is trial 27 with value: 21.301459630860855.
# [I 2024-12-03 11:54:38,461] Trial 30 finished with value: 22.128028235693748 and parameters: {'learning_rate': 0.30115638320811755, 'max_depth': 3, 'n_estimators': 40}. Best is trial 27 with value: 21.301459630860855.
# [I 2024-12-03 11:54:39,275] Trial 31 finished with value: 21.426164703892994 and parameters: {'learning_rate': 0.060127835902941476, 'max_depth': 4, 'n_estimators': 49}. Best is trial 27 with value: 21.301459630860855.
# [I 2024-12-03 11:54:40,310] Trial 32 finished with value: 21.129178084241506 and parameters: {'learning_rate': 0.06066585004291361, 'max_depth': 4, 'n_estimators': 63}. Best is trial 32 with value: 21.129178084241506.
# [I 2024-12-03 11:54:40,772] Trial 33 finished with value: 24.7990110985937 and parameters: {'learning_rate': 0.013664716449918596, 'max_depth': 3, 'n_estimators': 34}. Best is trial 32 with value: 21.129178084241506.
# [I 2024-12-03 11:54:41,654] Trial 34 finished with value: 22.08262011606744 and parameters: {'learning_rate': 0.17371655311019446, 'max_depth': 4, 'n_estimators': 52}. Best is trial 32 with value: 21.129178084241506.
# [I 2024-12-03 11:54:42,339] Trial 35 finished with value: 20.73154098004057 and parameters: {'learning_rate': 0.056632411939651156, 'max_depth': 2, 'n_estimators': 70}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:43,015] Trial 36 finished with value: 21.148565987794015 and parameters: {'learning_rate': 0.12756633813846527, 'max_depth': 2, 'n_estimators': 73}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:43,659] Trial 37 finished with value: 21.190266104674325 and parameters: {'learning_rate': 0.11796620971059457, 'max_depth': 2, 'n_estimators': 68}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:44,342] Trial 38 finished with value: 21.126863194242468 and parameters: {'learning_rate': 0.11723377211824415, 'max_depth': 2, 'n_estimators': 71}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:45,027] Trial 39 finished with value: 21.05175091694688 and parameters: {'learning_rate': 0.10774817938701313, 'max_depth': 2, 'n_estimators': 72}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:45,969] Trial 40 finished with value: 21.245460174128773 and parameters: {'learning_rate': 0.10358443273138034, 'max_depth': 2, 'n_estimators': 105}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:46,656] Trial 41 finished with value: 21.44361544508305 and parameters: {'learning_rate': 0.18275150094973336, 'max_depth': 2, 'n_estimators': 74}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:47,356] Trial 42 finished with value: 21.903000654826368 and parameters: {'learning_rate': 0.2269371050740921, 'max_depth': 2, 'n_estimators': 72}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:48,308] Trial 43 finished with value: 21.238692790940526 and parameters: {'learning_rate': 0.11560632660364151, 'max_depth': 3, 'n_estimators': 76}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:49,073] Trial 44 finished with value: 21.139950519121214 and parameters: {'learning_rate': 0.14807089541768048, 'max_depth': 2, 'n_estimators': 81}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:49,726] Trial 45 finished with value: 21.734556126645707 and parameters: {'learning_rate': 0.15113707036433943, 'max_depth': 3, 'n_estimators': 50}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:50,485] Trial 46 finished with value: 22.450559204762094 and parameters: {'learning_rate': 0.42867650916188876, 'max_depth': 2, 'n_estimators': 81}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:51,751] Trial 47 finished with value: 20.83763009277221 and parameters: {'learning_rate': 0.04403275579389371, 'max_depth': 3, 'n_estimators': 97}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:53,226] Trial 48 finished with value: 21.415985565431274 and parameters: {'learning_rate': 0.04631154002038976, 'max_depth': 3, 'n_estimators': 115}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:55,105] Trial 49 finished with value: 22.924163229205575 and parameters: {'learning_rate': 0.04057748353973493, 'max_depth': 10, 'n_estimators': 56}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:56,359] Trial 50 finished with value: 21.37728490752719 and parameters: {'learning_rate': 0.015244602756914707, 'max_depth': 3, 'n_estimators': 94}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:57,002] Trial 51 finished with value: 21.137244693564252 and parameters: {'learning_rate': 0.10592954150806111, 'max_depth': 2, 'n_estimators': 67}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:57,641] Trial 52 finished with value: 21.024315474065478 and parameters: {'learning_rate': 0.0843863695943164, 'max_depth': 2, 'n_estimators': 65}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:54:59,986] Trial 53 finished with value: 21.55037901709878 and parameters: {'learning_rate': 0.08166437385264236, 'max_depth': 3, 'n_estimators': 181}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:00,476] Trial 54 finished with value: 21.125457427436732 and parameters: {'learning_rate': 0.07527509964648153, 'max_depth': 2, 'n_estimators': 46}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:01,594] Trial 55 finished with value: 21.186395742527363 and parameters: {'learning_rate': 0.033620173065976554, 'max_depth': 2, 'n_estimators': 124}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:02,552] Trial 56 finished with value: 21.05022965587863 and parameters: {'learning_rate': 0.07850662469483266, 'max_depth': 2, 'n_estimators': 100}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:03,524] Trial 57 finished with value: 21.127830339707664 and parameters: {'learning_rate': 0.07406446038804977, 'max_depth': 2, 'n_estimators': 102}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:04,660] Trial 58 finished with value: 20.823463385823374 and parameters: {'learning_rate': 0.03577553919648853, 'max_depth': 3, 'n_estimators': 94}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:05,801] Trial 59 finished with value: 20.803107684485816 and parameters: {'learning_rate': 0.03258091568572286, 'max_depth': 3, 'n_estimators': 96}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:07,164] Trial 60 finished with value: 21.63126878382442 and parameters: {'learning_rate': 0.013126761466060757, 'max_depth': 3, 'n_estimators': 110}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:08,333] Trial 61 finished with value: 20.87683104346121 and parameters: {'learning_rate': 0.04602209274938694, 'max_depth': 3, 'n_estimators': 96}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:09,616] Trial 62 finished with value: 20.79875698171718 and parameters: {'learning_rate': 0.036964514213760444, 'max_depth': 3, 'n_estimators': 95}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:10,968] Trial 63 finished with value: 20.852902299643805 and parameters: {'learning_rate': 0.04027910853313659, 'max_depth': 4, 'n_estimators': 88}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:12,383] Trial 64 finished with value: 21.028683680434025 and parameters: {'learning_rate': 0.036601302810731894, 'max_depth': 4, 'n_estimators': 94}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:13,714] Trial 65 finished with value: 20.90141699493841 and parameters: {'learning_rate': 0.04564668499248199, 'max_depth': 4, 'n_estimators': 88}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:15,028] Trial 66 finished with value: 21.1323066072676 and parameters: {'learning_rate': 0.031070000467838733, 'max_depth': 3, 'n_estimators': 110}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:17,194] Trial 67 finished with value: 21.771790146826657 and parameters: {'learning_rate': 0.024081281997734655, 'max_depth': 5, 'n_estimators': 119}. Best is trial 35 with value: 20.73154098004057.
# [I 2024-12-03 11:55:18,292] Trial 68 finished with value: 20.640231012139203 and parameters: {'learning_rate': 0.04949201196244717, 'max_depth': 3, 'n_estimators': 88}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:19,707] Trial 69 finished with value: 22.000772337479713 and parameters: {'learning_rate': 0.010989448230845453, 'max_depth': 4, 'n_estimators': 88}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:20,775] Trial 70 finished with value: 22.27992744269154 and parameters: {'learning_rate': 0.31920475534858717, 'max_depth': 3, 'n_estimators': 86}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:21,945] Trial 71 finished with value: 21.0313574355877 and parameters: {'learning_rate': 0.0560804847494383, 'max_depth': 3, 'n_estimators': 94}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:23,119] Trial 72 finished with value: 20.867753861175583 and parameters: {'learning_rate': 0.042443853024687055, 'max_depth': 3, 'n_estimators': 98}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:24,773] Trial 73 finished with value: 21.1749544772801 and parameters: {'learning_rate': 0.027877058622871063, 'max_depth': 4, 'n_estimators': 106}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:27,156] Trial 74 finished with value: 22.521616573978214 and parameters: {'learning_rate': 0.09613659438410203, 'max_depth': 9, 'n_estimators': 79}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:28,346] Trial 75 finished with value: 20.936175287384675 and parameters: {'learning_rate': 0.04742722522111703, 'max_depth': 3, 'n_estimators': 98}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:30,477] Trial 76 finished with value: 21.86758670485264 and parameters: {'learning_rate': 0.0729834739122614, 'max_depth': 5, 'n_estimators': 114}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:31,938] Trial 77 finished with value: 22.981311953072 and parameters: {'learning_rate': 0.3802536432309256, 'max_depth': 4, 'n_estimators': 91}. Best is trial 68 with value: 20.640231012139203.
# [I 2024-12-03 11:55:32,969] Trial 78 finished with value: 20.587978936809485 and parameters: {'learning_rate': 0.029049685698178868, 'max_depth': 3, 'n_estimators': 85}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:33,914] Trial 79 finished with value: 20.835224145545478 and parameters: {'learning_rate': 0.024633614966976615, 'max_depth': 3, 'n_estimators': 78}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:34,966] Trial 80 finished with value: 20.914231649252358 and parameters: {'learning_rate': 0.020042870694824903, 'max_depth': 3, 'n_estimators': 83}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:35,974] Trial 81 finished with value: 23.158930206980664 and parameters: {'learning_rate': 0.49813425223043983, 'max_depth': 3, 'n_estimators': 85}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:37,272] Trial 82 finished with value: 21.51027416549054 and parameters: {'learning_rate': 0.06763978411885815, 'max_depth': 3, 'n_estimators': 107}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:38,466] Trial 83 finished with value: 20.93220218110339 and parameters: {'learning_rate': 0.028797102580450238, 'max_depth': 4, 'n_estimators': 77}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:39,586] Trial 84 finished with value: 20.765077913964813 and parameters: {'learning_rate': 0.05193756540162091, 'max_depth': 3, 'n_estimators': 90}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:42,571] Trial 85 finished with value: 22.25494251295283 and parameters: {'learning_rate': 0.05836188521833102, 'max_depth': 8, 'n_estimators': 102}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:43,390] Trial 86 finished with value: 20.90778919703936 and parameters: {'learning_rate': 0.054142954312039644, 'max_depth': 3, 'n_estimators': 60}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:44,639] Trial 87 finished with value: 20.888269702156112 and parameters: {'learning_rate': 0.02245712795350019, 'max_depth': 3, 'n_estimators': 91}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:46,102] Trial 88 finished with value: 21.213350323268106 and parameters: {'learning_rate': 0.08842863540086057, 'max_depth': 4, 'n_estimators': 81}. Best is trial 78 with value: 20.587978936809485.
# [I 2024-12-03 11:55:47,140] Trial 89 finished with value: 20.494129412753242 and parameters: {'learning_rate': 0.03603075049685412, 'max_depth': 3, 'n_estimators': 84}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:48,094] Trial 90 finished with value: 22.362699173998713 and parameters: {'learning_rate': 0.01155666887289853, 'max_depth': 3, 'n_estimators': 77}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:49,073] Trial 91 finished with value: 20.512252325026342 and parameters: {'learning_rate': 0.03467078956686369, 'max_depth': 3, 'n_estimators': 84}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:49,941] Trial 92 finished with value: 20.807931727560405 and parameters: {'learning_rate': 0.06715007333609897, 'max_depth': 3, 'n_estimators': 69}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:50,551] Trial 93 finished with value: 20.78377440189796 and parameters: {'learning_rate': 0.06778969446793637, 'max_depth': 2, 'n_estimators': 69}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:51,184] Trial 94 finished with value: 20.788302452265224 and parameters: {'learning_rate': 0.07332523150747387, 'max_depth': 2, 'n_estimators': 71}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:51,700] Trial 95 finished with value: 21.289321656741354 and parameters: {'learning_rate': 0.09755597784242871, 'max_depth': 2, 'n_estimators': 58}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:52,355] Trial 96 finished with value: 20.762114652305804 and parameters: {'learning_rate': 0.0529928098614849, 'max_depth': 2, 'n_estimators': 73}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:52,839] Trial 97 finished with value: 21.18373001292921 and parameters: {'learning_rate': 0.053621420854441486, 'max_depth': 2, 'n_estimators': 54}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:53,415] Trial 98 finished with value: 21.053628758960606 and parameters: {'learning_rate': 0.08250141811802021, 'max_depth': 2, 'n_estimators': 65}. Best is trial 89 with value: 20.494129412753242.
# [I 2024-12-03 11:55:54,043] Trial 99 finished with value: 20.743223805812526 and parameters: {'learning_rate': 0.06598194176791024, 'max_depth': 2, 'n_estimators': 73}. Best is trial 89 with value: 20.494129412753242.
# Best hyperparameters: {'learning_rate': 0.03603075049685412, 'max_depth': 3, 'n_estimators': 84}
# Best score: 20.494129412753242

# %%
# from plotly.io import show
# fig = optuna.visualization.plot_contour(study, params=["learning_rate", "max_depth"])
# show(fig)
